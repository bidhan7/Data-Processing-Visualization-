# %% [markdown]
# <a href="https://colab.research.google.com/github/bidhan7/Data-Processing-Visualization-/blob/main/Quiz_28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DATA VISIUALIZATION
# ## Associations

# %% [markdown]
# I am making some interesting scatterplot using seaborn. Importing all the necessary python functions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

df = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv')

df.head()
# Out:
#    Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 0           0   2022-01-01       Freestyle      9.30    77       123
# 1           1   2022-01-01       Freestyle      3.44    96        55
# 2           2   2022-01-01  Indoor Cycling      6.34    85        33
# 3           3   2022-01-01         Walking      7.91    42        82
# 4           4   2022-01-01      Open Water      8.99    36       131
#
#    total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 0          NaN      18.88       168.54       138.30  ...      NaN      NaN
# 1          NaN      29.65       125.92       292.81  ...      NaN      NaN
# 2          NaN      17.85        81.93       323.69  ...      NaN      NaN
# 3       1571.0      22.10        29.63       180.16  ...    28:58    07:58
# 4          NaN      25.83        64.55       342.89  ...      NaN      NaN
#
#   avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %% [markdown]
# ### Scatterplot

# %% [markdown]
# Here, we've supplied the df as the data argument, and provided the features we want to visualize as the x and y arguments.

# %%
sns.scatterplot(data = df, y= 'calories',x = 'workout_type')

# %%
sns.scatterplot(data = df, x = 'workout_type', y = 'time', hue = 'calories',)

# %% [markdown]
# Seaborn allows us to construct a FacetGrid object, which we can use to facet the data and construct multiple, related plots, one next to the other.Let's try to do that.

# %%
grid = sns.FacetGrid(df, col = "workout_type", hue = "workout_type", col_wrap=4)
grid.map(sns.scatterplot, "distance", "calories")

grid.add_legend()

plt.show()

# %% [markdown]
# Seaborn doesn't come with any built-in 3D functionality, unfortunately. It's an extension of Matplotlib and relies on it for the heavy lifting in 3D. Though, we can style the 3D Matplotlib plot, using Seaborn.

# %%
from mpl_toolkits.mplot3d import Axes3D
sns.set(style = "darkgrid")

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = df['calories']
y = df['distance']
z = df['time']

ax.set_xlabel("calories")
ax.set_ylabel("distance")
ax.set_zlabel("time")

ax.scatter(x, y, z)

plt.show()

# %% [markdown]
# Presenting 5 diffirent variable in one graph!

# %%
sns.relplot(x="distance", y="time", hue="calories",style="total_steps",
            col="workout_type",col_wrap=4, data=df);
