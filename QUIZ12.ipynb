# %% [markdown]
# <a href="https://colab.research.google.com/github/bidhan7/Data-Processing-Visualization-/blob/main/QUIZ12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Bidhan Subedi
# ## DATA PROCESSING VISUALIZATION

# %% [markdown]
# # QUIZ 12

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# I got this code from dr Nicholas Jacob. I have to be authenticated to run the codes below.

# %%
# %%bigquery --project data-visualization-338723
# SELECT
#   COUNT(*) as total_rows
# FROM `bigquery-public-data.london_fire_brigade.fire_brigade_service_calls`
# Out:
#    total_rows
# 0       32247

# %% [markdown]
# Total *rows* are 32247.

# %%
# %%bigquery --project data-visualization-338723
# SELECT *
# FROM `bigquery-public-data.london_fire_brigade.fire_brigade_service_calls`
# LIMIT 30
# Out:
#     incident_number  ... num_pumps_attending
# 0   000320-01012017  ...                   2
# 1   003727-09012017  ...                   2
# 2   003762-09012017  ...                   2
# 3   006403-16012017  ...                   2
# 4   010947-26012017  ...                   1
# 5   014169-03022017  ...                   5
# 6   016263-08022017  ...                   2
# 7   016865-09022017  ...                   1
# 8   017092-10022017  ...                   1
# 9   024609-27022017  ...                   1
# 10  025352-01032017  ...                   1
# 11  025355-01032017  ...                   2
# 12  033935-21032017  ...                   2
# 13  034332-22032017  ...                   2
# 14  034347-22032017  ...                   2
# 15  036063-26032017  ...                   2
# 16  037971-30032017  ...                   1
# 17  038036-30032017  ...                   1
# 18  039917-03042017  ...                   2
# 19  043780-10042017  ...                   1
# ...

# %% [markdown]
# Using where command to find 'False alarm'.

# %%
# %%bigquery --project data-visualization-338723
# SELECT COUNT(*) as false_alarm_during_10pm_to_5am
# FROM `bigquery-public-data.london_fire_brigade.fire_brigade_service_calls`
# where incident_group = "False Alarm" AND (hour_of_call >=22 OR hour_of_call <=4)
# Out:
#    false_alarm_during_10pm_to_5am
# 0                            2825

# %% [markdown]
# Average number of num_pumps_attending when there is a Fire

# %%
# %%bigquery --project data-visualization-338723
# SELECT incident_group, AVG(num_pumps_attending) as Average_pumps
# FROM `bigquery-public-data.london_fire_brigade.fire_brigade_service_calls`
# GROUP BY incident_group
# Out:
#     incident_group  Average_pumps
# 0      False Alarm       1.725776
# 1             Fire       1.633012
# 2  Special Service       1.177192

# %% [markdown]
#  Largest number of num_pumps_attending to a Road Vehicle property_category

# %%
# %%bigquery --project data-visualization-338723
# SELECT property_category, MAX(num_pumps_attending) as max_pumps
# FROM `bigquery-public-data.london_fire_brigade.fire_brigade_service_calls`
# GROUP BY property_category
# Out:
#    property_category  max_pumps
# 0           Dwelling          7
# 1    Non Residential          7
# 2  Other Residential          5
# 3               Boat          3
# 4  Outdoor Structure          5
# 5       Rail Vehicle          4
# 6            Outdoor          6
# 7       Road Vehicle          6
# 8           Aircraft          4
