# %% [markdown]
# <a href="https://colab.research.google.com/github/bidhan7/Data-Processing-Visualization-/blob/main/Quiz%2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DATA PROCESSING VISIUALIZATION
# ## Bidhan Subedi (222955)
# ## Graphical Sophistication

# %% [markdown]
# #### Find two charts that were not discussed during class today and examine them for graphical excellence, sophistication and integrity. You should write about 100 words about each graph and include the image and a link to where it can be found.

# %% [markdown]
# ### 1)
#
# https://symposium.foragerone.com/okrd22/presentations/37502

# %% [markdown]
# ![1st.png](data:image/png;base64,...)

# %% [markdown]
# This research post covers the difficulties that a new refinery could confront which contributes to the absence of new refineries being constructed. There is one bar-chart in the post which presents U.S. atmospheric crude oil distillation capacity through 2012-2021.
#
# We can see that X- axis is showing the years. The dark  blue color is indexed as operating and light blue is idle refineries. Total operable oil refineries is given at the top of each bar in respective years. I am not 100% sure what unit is Y-axis is trying to represent.
#
# At top of the chart it also mentions that million barrels per calendar day as of January 1. I am assuming this, in 2012 there was ((17.3*365)* 1,000,000) total operable refineries. But there is no numeric presentation for idle  or operating refineries.
#
# There is also another graphical presentation of oil refineries all over U.S. map. Some of the refiners are indexed but not all of them.
