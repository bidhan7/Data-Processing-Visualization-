# %% [markdown]
# <a href="https://colab.research.google.com/github/bidhan7/Data-Processing-Visualization-/blob/main/Quiz10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization
# ## Bidhan Subedi
# ### Selenium

# %% [markdown]
# Q. Use python to browse to google. Search for something of interest and go to the first link by clicking I am feeling lucky. Return the html from that first page.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# Installing and loading selenium with its driver and chromium.

# %%
# !apt update
# !apt install chromium-chromedriver
# !pip install selenium
# set options to be headless
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# open it, go to a website, and get results
driver = webdriver.Chrome('chromedriver',options=options)
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# ...

# %% [markdown]
# Now with all that done, I am going to use selenium commands to crawl through the webpage and get the work done.
#
# I'm importing` By `and `Keys` from selenium to get to a searcbox and type some inputs.
#
# I first get the xpath of a google search box UI and use send_keys method to type a keyword and press enter.

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys 

url = "https://www.google.com"
driver.get(url)
element = driver.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
element.send_keys('Pizza')
element.send_keys(Keys.ENTER)

# %% [markdown]
# After this code, I get a google search page which searches about the keyword provided above. In this case, I get a result of a superbowl keyword.

# %%
driver.current_url
# Out:
# 'https://www.google.com/search?q=Pizza&source=hp&ei=49r8YdGCLMerwbkPzqiPoA8&iflsig=AHkkrS4AAAAAYfzo8y6G0PcXETmM__nsoA0npHmxPNwV&ved=0ahUKEwiRgPWXyOX1AhXHVTABHU7UA_QQ4dUDCAo&uact=5&oq=Pizza&gs_lcp=Cgdnd3Mtd2l6EAMyEQguEIAEELEDEIMBEMcBEKMCMg4IABCABBCxAxCDARDJAzIICAAQgAQQsQMyCAgAEIAEELEDMgUIABCABDIICAAQgAQQsQMyCAgAEIAEELEDMg4ILhCABBCxAxDHARCjAjILCAAQgAQQsQMQgwEyBQgAEIAEUABYMmDGAWgAcAB4AoABaogB0gKSAQMyLjKYAQCgAQE&sclient=gws-wiz'

# %% [markdown]
# Now, I am going to navigate to the first result and open the link associated with it. That means, I am opening a first search result from a google search.

# %%
result = driver.find_element(By.CLASS_NAME, 'yuRUbf')
result.click()

# %% [markdown]
# Since the first google search result is of nfl official website so I am going to call current_url method to get where we are at which should match nfl.com.

# %%
print(driver.current_url)
driver.title
# Out:
# https://www.google.com/search?q=Pizza&source=hp&ei=49r8YdGCLMerwbkPzqiPoA8&iflsig=AHkkrS4AAAAAYfzo8y6G0PcXETmM__nsoA0npHmxPNwV&ved=0ahUKEwiRgPWXyOX1AhXHVTABHU7UA_QQ4dUDCAo&uact=5&oq=Pizza&gs_lcp=Cgdnd3Mtd2l6EAMyEQguEIAEELEDEIMBEMcBEKMCMg4IABCABBCxAxCDARDJAzIICAAQgAQQsQMyCAgAEIAEELEDMgUIABCABDIICAAQgAQQsQMyCAgAEIAEELEDMg4ILhCABBCxAxDHARCjAjILCAAQgAQQsQMQgwEyBQgAEIAEUABYMmDGAWgAcAB4AoABaogB0gKSAQMyLjKYAQCgAQE&sclient=gws-wiz
# 'Access Denied'

# %% [markdown]
# I need to return the html of this page so lets get to work with beautiful soup and html parser.

# %%
soup = BeautifulSoup(driver.page_source)
# print the html from a page
soup
# Out:
# <html><head>
# <title>Access Denied</title>
# </head><body>
# <h1>Access Denied</h1>
#
# You don't have permission to access "http://www.pizzahut.com/" on this server.<p>
# Reference #18.d6292117.1643961063.e61a32e
#
#
# </p></body></html>

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys 

url = "https://www.google.com"
driver.get(url)
element = driver.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
element.send_keys('Buddha')
element.send_keys(Keys.ENTER)

# %%
driver.current_url
# Out:
# 'https://www.google.com/search?q=Everest&source=hp&ei=O9v8YdJd3ZXBuQ-DqaOQDQ&iflsig=AHkkrS4AAAAAYfzpS4y-7wROWAtqWrkQtbYHteM9dEor&ved=0ahUKEwiS58TByOX1AhXdSjABHYPUCNIQ4dUDCAo&uact=5&oq=Everest&gs_lcp=Cgdnd3Mtd2l6EANQAFgmYE1oAHAAeACAAQCIAQCSAQCYAQCgAQE&sclient=gws-wiz'

# %%
result = driver.find_element(By.CLASS_NAME, 'yuRUbf')
result.click()

# %%
print(driver.current_url)
driver.title
# Out:
# https://www.google.com/search?q=Buddha&source=hp&ei=bNv8Yc-_FtaMwbkPiPio-A8&iflsig=AHkkrS4AAAAAYfzpfLKqMEyRGNBzuo9UTz3ThwMBkdoy&ved=0ahUKEwjPpYnZyOX1AhVWRjABHQg8Cv8Q4dUDCAo&uact=5&oq=Buddha&gs_lcp=Cgdnd3Mtd2l6EANQAFgpYEdoAHAAeACAAQCIAQCSAQCYAQCgAQE&sclient=gws-wiz
# 'Buddha - Google Search'

# %%
soup = BeautifulSoup(driver.page_source)
# print the html from a page
soup
# Out:
# <html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en"><head><meta charset="utf-8"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>wild honey - Google Search</title><script nonce="USlKWSHVBtQ4ToQpwmMzWw==">(function(){
# var b=window.addEventListener;window.addEventListener=function(a,c,d){"unload"!==a&&b(a,c,d)};}).call(this);(function(){window.google={kEI:'6Nr8YfW2Ht2awbkP6ZOKyAc',kEXPI:'31',kBL:'a6iw'};google.sn='web';google.kHL='en';})();(function(){
# var f=this||self;var h,k=[];function l(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||h}function m(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}
# ...
