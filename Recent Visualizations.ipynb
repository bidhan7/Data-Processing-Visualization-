# %% [markdown]
# <a href="https://colab.research.google.com/github/bidhan7/Data-Processing-Visualization-/blob/main/Recent%20Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Global Warming**
# ##**DATA VISIUALIZATION (CPSMA-4313)**
# ##**Instructor: Dr. Nicholas Jacob**
# ##**Review Visiualization**
# ##**Bidhan Subedi (222955)**

# %% [markdown]
# >**Abstract:** The rough balance between the net uptake of carbon into deep pools (mostly the deep ocean) and the rate at which the oceans warm in response to an energy imbalance is the foundation of this relationship. A after CO2 emissions halt, global temperature is virtually stable to zeroth order. As a result, future warming is completely reliant on future emissions. These correlations imply that if cumulative emissions cease (i.e. net-zero), the temperature will eventually rise.

# %% [markdown]
# ## **Topic**
#
# The topic that i have selected is climate change due to Global warming. The article seems like it has recent data and is from Nov 21,2021. It is timely data as we are predicting how much warming projection in future with CO2 emmision.
#
# Understanding the data at its heart provides a bridge to understanding climate. Scientists today rely on minute observations of temperatures, ocean currents, soil moisture, air quality, cloud cover, and hundreds of other occurrences on Earth and in its atmosphere, resulting in a flood of data.

# %% [markdown]
# ## **Visualization**

# %% [markdown]
# The below diagram shows the relationship between cumulative carbon emissions and temperature (SPM AR6).
#
# [Graph link](https://www.realclimate.org/index.php/archives/2021/11/net-zero-not-zero/)

# %% [markdown]
# With more and better data and modeling, it's become evident that, to a first approximation, eventual anthropogenic warming from carbon dioxide is linked to cumulative emissions. This graphic is from the AR6 SPM:

# %% [markdown]
# ![proposal.png](data:image/png;base64,...)

# %% [markdown]
# The visiualization looks little complicated. I am really intrested to know about this kind of visiualization!. It is showing the histroy of global warming. It is just line graph and the five colors with SSP(Shared Socioeconomic Pathway) has diffirent numbers.Two graphical representation is in same graph below. At the top it is showing the near-linear relationship between the cumulative CO2 emmissions and global warming for five illustrative scenarios until year 2050!
# The bottom race-chart, half of the chart is colorful! The one without no colors is historical representation of cumulative CO2 emmissions between 1850 and 2019. The one with colors is projections representing  CO2 emmissions between 2020 and 2050.
#
#
# SSP1-1.9: This is the IPCC's most optimistic scenario, describing a world in which global CO2 emissions are reduced to zero by 2050. Societies change their attention from economic growth to total well-being, resulting in more sustainable behaviors.

# %% [markdown]
#  ![proposal 1.png](data:image/png;base64,...)

# %% [markdown]
# This is a significant result, and it underpins the new pledges to attain net-zero emissions by 2030/2040/2050, among other targets, as part of the COP26 upgrade to Nationally Determined Contributions (NDCs).
#
#
# The concept stems from important physical science findings, such as those highlighted in the Special Report on 1.5°C and expanded upon in the most recent IPCC report, that future warming is linked to future emissions, and that warming will effectively stop only when anthropogenic CO2 emissions are balanced by anthropogenic CO2 removals. However, as several campaigners have correctly pointed out, large-scale CO2 removals have yet to be tested, and relying on them to balance out emissions to any meaningful level is akin to not really committing to net zero at all. Their argument is that "net-zero" is not the same as "zero," and hence will serve as a cloak for inaction on climate change.

# %% [markdown]
# ### Countries Race To Net Zero
#
# The time to talk about net zero goals has passed, and the time to put them into action has begun.
# President Biden pressed countries to either accelerate or commit to carbon neutral goals at the United States Climate Summit in April 2021.
# It's a follow-up to the Paris Agreement, which commits signatories to carbon neutrality in emissions by the second half of the twenty-first century. However, the period 2050–2100 is broad, and climate change is becoming both more visible and more dangerous.

# %% [markdown]
# [Graph link](https://www.visualcapitalist.com/race-to-net-zero-carbon-neutral-goals-by-country/)

# %% [markdown]
# ![2 photo.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# I found this graphic very excellent. It looks great how graph has indexed commitment and targeted year with distinct colors and patterns. There are all the countries who have made the carbon neutral pledge. This map has break down the pledges by target year and level of commitment. Only thing which is bothering me in this graph is I didn't see Russia in outer semi-circle map. I am not sure if Russia is participating in net zero goal or it has already achieved by now? As in the index it shows white for achieved and other white for none made. It is little difficult to interpret two white color.
# Australia and Singapore have carbon neutral ambitions for the second half of 21st century, no concrete date. The suprising thing is that Bhutan and Suriname have already achieved the carbon neutral goals.

# %% [markdown]
# ### Warming Projections By 2100
#
# When the United Nations examined each country's pledges under the Paris Agreement in mid-September, it discovered that even if every pledge is kept, temperatures will rise by around 2.7 degrees Celsius (4.86 degrees Fahrenheit) this century.

# %% [markdown]
# [Graph link](https://theconversation.com/more-companies-pledge-net-zero-emissions-to-fight-climate-change-but-what-does-that-really-mean-166547)

# %% [markdown]
# ![Screenshot (3).png](data:image/png;base64,...)

# %% [markdown]
# As we can see this above figure is simple graph. X-axis represent year and Y-axis represent Global GHG emissions. As we can see black line as historical emmissions and then it splits into 5 diffirent lines. Every line represents the warming projection. Also every lines are colored diffirent and indexed at right of the graph.
#
# Keeping global warming to 1.5 C will require negative greenhouse gas emissions.

# %% [markdown]
# ### Similiraties and diffirence with Visiualization

# %% [markdown]
# The main similarities found after analyzing these visiualization is that to avoid the most dangerous and irreversible effects of climate change, global warming should be limited to 1.5 degrees Celsius. That means carbon emissions must be zero by 2050, a dramatic departure from the current trajectory.
#
# The diffirence would be each of these visiualization is representing diffirent data. As the 1st visiualization show the near-linear relationship between the cumulative CO2 emmissions and global warming for five illustrative scenarios until year 2050! 2nd visiualization show carbon neutral goals of all countries in Earth and the final visiualization also shows the warming projection by 2100.

# %% [markdown]
# ## REFERENCES
#
# https://www.realclimate.org/index.php/archives/2021/11/net-zero-not-zero/
#
# https://theglobalobservatory.org/2021/12/new-climate-data-visualizations-2021/
#
# https://www.ipcc.ch/report/ar6/wg1/
#
# https://www.reuters.com/business/environment/un-climate-reports-five-futures-decoded-2021-08-09/#:~:text=SSP1%2D1.9%3A%20The%20IPCC's%20most,growth%20to%20overall%20well%2Dbeing.
#
# https://theconversation.com/more-companies-pledge-net-zero-emissions-to-fight-climate-change-but-what-does-that-really-mean-166547
