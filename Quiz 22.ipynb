# %% [markdown]
# <a href="https://colab.research.google.com/github/bidhan7/Data-Processing-Visualization-/blob/main/Quiz%2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # This is formatted as code
# ```

# %% [markdown]
# ### Head over to Oklahaoma Research Day. Spend some time looking at three posters that include statistical charts or graphs. Include links to each. Discuss the strengths and weaknesses of each. Do they display excellence or do they lie?

# %% [markdown]
# https://symposium.foragerone.com/okrd22/presentations/37431

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# This poster include three  statistical graph. All three chart display excellence. I didn't understood the third graph. In 1st two graph there id index.

# %% [markdown]
# https://symposium.foragerone.com/okrd22/presentations/37191

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# There are two graphs shown in above poster.
