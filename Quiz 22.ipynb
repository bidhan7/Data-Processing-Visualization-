# %% [markdown]
# <a href="https://colab.research.google.com/github/bidhan7/Data-Processing-Visualization-/blob/main/Quiz%2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA PROCESSING VIZUALIZATION
# ## Bidhan Subedi (222955)
# ## Quiz 22

# %% [markdown]
# ### Head over to [Oklahaoma Research Day](https://symposium.foragerone.com/okrd22). Spend some time looking at three posters that include statistical charts or graphs. Include links to each. Discuss the strengths and weaknesses of each. Do they display excellence or do they lie?

# %% [markdown]
# ## 1
#
# https://symposium.foragerone.com/okrd22/presentations/37431

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# This poster include three  statistical graph. 1st graph is about Phage stability(titer vs temp). Y-axis represent the titer. Titer of virus stock can be calculated in plaque forming units(PFU) per milliter. To determine the virus titer, plaques are counted. X- axis represents temperature in degree Celcius. Incubation time is indicated by diffirent colors as index. This is excellent graph.
#
# Second graph is Titer vs PH. It seems phage titer is fairly stable at most pH level except pH=3. It dropped by about six order of magnitude. This graph also display excellence.
#
# In third one it shows the ration of PFU at time relative to PFUs at time 0 vs, time in hours post-infection.The most increment is seen between 3.5 to 4.5 hours post-infection.
# It don't seem like there are weakness in the graphs in this poster.

# %% [markdown]
# ## 2
#
# https://symposium.foragerone.com/okrd22/presentations/37191

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# There are two graphs shown in above poster. This is little weird one compared to other graph that i have seen before. In fig 2 & 3 we can see Y-axis is represent by formaldehyde and X-axis is presented by Time (minute).
#
# Fig 2 represents formaldehyde emission from bone tissue with time upon opening the lead of a container storing the bone tissue at diffirent time.
#
# There is also index for both figure which makes easy to interpret.
#
# Fig 3 represents formaldehyde emission from bone tissue with time after cutting the tissue using teethed blade without and with vacuum pressure & diamond coated blade without vaccum pressure.

# %% [markdown]
# ## 3
#
# https://symposium.foragerone.com/okrd22/presentations/37312

# %% [markdown]
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# This are two scatterplot shown above. Yellow represent Communication building and green represent Howell Hall. Both of the scatter plot doesn't seem linear at all. As we know if it goes from left to right, you can read the trend as increasing (positive) or decreasing (negative). I would say both the plot represent no correlation. The most values are near origin. 1st plot has little more value going upward.
